# %% [markdown]
# This notebook provides a minimal working example of the image-to-painting translation (progressive rendering) in the preprint paper "Stylized Neural Painting, arXiv:2011.08114."
#
# [Project Page](https://jiupinjia.github.io/neuralpainter/) | [GitHub](https://github.com/jiupinjia/stylized-neural-painting) | [Preprint](https://arxiv.org/abs/2011.08114)

# %% [markdown]
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><span xmlns:dct="http://purl.org/dc/terms/" property="dct:title">   The project </a> is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %%
# Clone the repository
# !git clone https://github.com/jiupinjia/stylized-neural-painting
# Out:
# Cloning into 'stylized-neural-painting'...
# remote: Enumerating objects: 198, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 198 (delta 29), reused 26 (delta 10), pack-reused 143
# Receiving objects: 100% (198/198), 3.63 MiB | 8.11 MiB/s, done.
# Resolving deltas: 100% (100/100), done.

# %%
cd stylized-neural-painting
# Out:
# /content/stylized-neural-painting

# %%
import argparse

import torch
# torch.cuda.current_device()
import torch.optim as optim

from painter import *
# Decide which device we want to run on
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# settings
parser = argparse.ArgumentParser(description='STYLIZED NEURAL PAINTING')
args = parser.parse_args(args=[])
args.img_path = './test_images/iceland.jpg' # path to input photo
args.renderer = 'oilpaintbrush' # [watercolor, markerpen, oilpaintbrush, rectangle]
args.canvas_color = 'black' # [black, white]
args.canvas_size = 512 # size of the canvas for stroke rendering'
args.keep_aspect_ratio = False # whether to keep input aspect ratio when saving outputs
args.max_m_strokes = 500 # max number of strokes
args.max_divide = 5 # divide an image up-to max_divide x max_divide patches
args.beta_L1 = 1.0 # weight for L1 loss
args.with_ot_loss = False # set True for imporving the convergence by using optimal transportation loss, but will slow-down the speed
args.beta_ot = 0.1 # weight for optimal transportation loss
args.net_G = 'zou-fusion-net' # renderer architecture
args.renderer_checkpoint_dir = './checkpoints_G_oilpaintbrush' # dir to load the pretrained neu-renderer
args.lr = 0.005 # learning rate for stroke searching
args.output_dir = './output' # dir to save painting results
args.disable_preview = True # disable cv2.imshow, for running remotely without x-display

# %% [markdown]
# Download pretrained neural renderer.

# %%
# Define some helper functions for downloading pretrained model
# taken from this StackOverflow answer: https://stackoverflow.com/a/39225039
import requests

def download_file_from_google_drive(id, destination):
    URL = "https://docs.google.com/uc?export=download"

    session = requests.Session()

    response = session.get(URL, params = { 'id' : id }, stream = True)
    token = get_confirm_token(response)

    if token:
        params = { 'id' : id, 'confirm' : token }
        response = session.get(URL, params = params, stream = True)

    save_response_content(response, destination)    

def get_confirm_token(response):
    for key, value in response.cookies.items():
        if key.startswith('download_warning'):
            return value

    return None

def save_response_content(response, destination):
    CHUNK_SIZE = 32768

    with open(destination, "wb") as f:
        for chunk in response.iter_content(CHUNK_SIZE):
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)

# %%
# download and unzip...
file_id = '1sqWhgBKqaBJggl2A8sD1bLSq2_B1ScMG'
destination = './checkpoints_G_oilpaintbrush.zip'
download_file_from_google_drive(file_id, destination)

# %%
# !unzip checkpoints_G_oilpaintbrush.zip
# Out:
# Archive:  checkpoints_G_oilpaintbrush.zip
#    creating: checkpoints_G_oilpaintbrush/
#   inflating: checkpoints_G_oilpaintbrush/last_ckpt.pt

# %% [markdown]
# Define the optimization loop the painter

# %%
def optimize_x(pt):

    pt._load_checkpoint()
    pt.net_G.eval()

    print('begin drawing...')

    PARAMS = np.zeros([1, 0, pt.rderr.d], np.float32)

    if pt.rderr.canvas_color == 'white':
        CANVAS_tmp = torch.ones([1, 3, 128, 128]).to(device)
    else:
        CANVAS_tmp = torch.zeros([1, 3, 128, 128]).to(device)

    for pt.m_grid in range(1, pt.max_divide + 1):

        pt.img_batch = utils.img2patches(pt.img_, pt.m_grid, pt.net_G.out_size).to(device)
        pt.G_final_pred_canvas = CANVAS_tmp

        pt.initialize_params()
        pt.x_ctt.requires_grad = True
        pt.x_color.requires_grad = True
        pt.x_alpha.requires_grad = True
        utils.set_requires_grad(pt.net_G, False)

        pt.optimizer_x = optim.RMSprop([pt.x_ctt, pt.x_color, pt.x_alpha], lr=pt.lr, centered=True)

        pt.step_id = 0
        for pt.anchor_id in range(0, pt.m_strokes_per_block):
            pt.stroke_sampler(pt.anchor_id)
            iters_per_stroke = int(500 / pt.m_strokes_per_block)
            for i in range(iters_per_stroke):
                pt.G_pred_canvas = CANVAS_tmp

                # update x
                pt.optimizer_x.zero_grad()

                pt.x_ctt.data = torch.clamp(pt.x_ctt.data, 0.1, 1 - 0.1)
                pt.x_color.data = torch.clamp(pt.x_color.data, 0, 1)
                pt.x_alpha.data = torch.clamp(pt.x_alpha.data, 0, 1)

                pt._forward_pass()
                pt._drawing_step_states()
                pt._backward_x()

                pt.x_ctt.data = torch.clamp(pt.x_ctt.data, 0.1, 1 - 0.1)
                pt.x_color.data = torch.clamp(pt.x_color.data, 0, 1)
                pt.x_alpha.data = torch.clamp(pt.x_alpha.data, 0, 1)

                pt.optimizer_x.step()
                pt.step_id += 1

        v = pt._normalize_strokes(pt.x)
        v = pt._shuffle_strokes_and_reshape(v)
        PARAMS = np.concatenate([PARAMS, v], axis=1)
        CANVAS_tmp = pt._render(PARAMS, save_jpgs=False, save_video=False)
        CANVAS_tmp = utils.img2patches(CANVAS_tmp, pt.m_grid + 1, pt.net_G.out_size).to(device)

    pt._save_stroke_params(PARAMS)
    final_rendered_image = pt._render(PARAMS, save_jpgs=False, save_video=True)

    return final_rendered_image

# %% [markdown]
# Now you can process your image

# %%
pt = ProgressivePainter(args=args)
final_rendered_image = optimize_x(pt)
# Out:
# initialize network with normal
# loading renderer from pre-trained checkpoint...
# begin drawing...
# iteration step 0, G_loss: 0.00000, step_acc: 4.89623, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 1, G_loss: 0.49835, step_acc: 5.02072, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 2, G_loss: 0.49087, step_acc: 5.13098, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 3, G_loss: 0.48365, step_acc: 5.25824, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 4, G_loss: 0.47504, step_acc: 5.40259, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 5, G_loss: 0.46534, step_acc: 5.48583, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 6, G_loss: 0.45899, step_acc: 5.62962, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 7, G_loss: 0.44936, step_acc: 5.71674, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 8, G_loss: 0.44342, step_acc: 5.82764, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 9, G_loss: 0.43634, step_acc: 5.95250, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 10, G_loss: 0.42852, step_acc: 6.01642, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 11, G_loss: 0.42477, step_acc: 6.18913, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 12, G_loss: 0.41516, step_acc: 6.32925, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 13, G_loss: 0.40706, step_acc: 6.48936, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 14, G_loss: 0.39712, step_acc: 6.60821, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 15, G_loss: 0.38921, step_acc: 6.77167, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 16, G_loss: 0.38044, step_acc: 6.88708, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 17, G_loss: 0.37291, step_acc: 7.00674, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 18, G_loss: 0.36595, step_acc: 7.08751, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 19, G_loss: 0.36089, step_acc: 7.15209, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 20, G_loss: 0.35723, step_acc: 7.21526, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 21, G_loss: 0.35277, step_acc: 7.24775, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 22, G_loss: 0.35113, step_acc: 7.35236, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 23, G_loss: 0.34440, step_acc: 7.39750, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 24, G_loss: 0.34146, step_acc: 7.42455, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 25, G_loss: 0.33958, step_acc: 7.44406, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 26, G_loss: 0.33816, step_acc: 7.47316, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 27, G_loss: 0.33624, step_acc: 7.50441, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 28, G_loss: 0.33453, step_acc: 7.52795, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 29, G_loss: 0.33286, step_acc: 7.54982, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 30, G_loss: 0.33133, step_acc: 7.56319, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 31, G_loss: 0.33049, step_acc: 7.57633, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 32, G_loss: 0.32963, step_acc: 7.59169, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 33, G_loss: 0.32871, step_acc: 7.60730, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 34, G_loss: 0.32762, step_acc: 7.63226, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 35, G_loss: 0.32659, step_acc: 7.67370, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 36, G_loss: 0.32462, step_acc: 7.69910, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 37, G_loss: 0.32363, step_acc: 7.73773, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 38, G_loss: 0.32162, step_acc: 7.76994, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 39, G_loss: 0.32013, step_acc: 7.79925, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 40, G_loss: 0.31888, step_acc: 7.81613, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 41, G_loss: 0.31834, step_acc: 7.83378, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 42, G_loss: 0.31746, step_acc: 7.84446, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 43, G_loss: 0.31706, step_acc: 7.85417, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 44, G_loss: 0.31672, step_acc: 7.86727, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 45, G_loss: 0.31622, step_acc: 7.88910, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 46, G_loss: 0.31557, step_acc: 7.91210, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 47, G_loss: 0.31471, step_acc: 7.92483, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 48, G_loss: 0.31419, step_acc: 7.93587, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 49, G_loss: 0.31369, step_acc: 7.94874, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 50, G_loss: 0.31319, step_acc: 7.96407, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 51, G_loss: 0.31264, step_acc: 7.97452, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 52, G_loss: 0.31227, step_acc: 7.97934, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 53, G_loss: 0.31202, step_acc: 7.99116, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 54, G_loss: 0.31167, step_acc: 7.99779, grid_scale: 1 / 5, strokes: 1 / 9
# iteration step 55, G_loss: 0.31122, step_acc: 8.24204, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 56, G_loss: 0.30191, step_acc: 8.39453, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 57, G_loss: 0.29562, step_acc: 8.50230, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 58, G_loss: 0.29054, step_acc: 8.57865, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 59, G_loss: 0.28729, step_acc: 8.61436, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 60, G_loss: 0.28544, step_acc: 8.70334, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 61, G_loss: 0.28179, step_acc: 8.70886, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 62, G_loss: 0.28141, step_acc: 8.80087, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 63, G_loss: 0.27840, step_acc: 8.82827, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 64, G_loss: 0.27705, step_acc: 8.93476, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 65, G_loss: 0.27390, step_acc: 8.98868, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 66, G_loss: 0.27161, step_acc: 9.16898, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 67, G_loss: 0.26668, step_acc: 9.28519, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 68, G_loss: 0.26302, step_acc: 9.34921, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 69, G_loss: 0.26081, step_acc: 9.43882, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 70, G_loss: 0.25804, step_acc: 9.49321, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 71, G_loss: 0.25605, step_acc: 9.52687, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 72, G_loss: 0.25472, step_acc: 9.50750, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 73, G_loss: 0.25529, step_acc: 9.57399, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 74, G_loss: 0.25280, step_acc: 9.58718, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 75, G_loss: 0.25241, step_acc: 9.58978, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 76, G_loss: 0.25219, step_acc: 9.59871, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 77, G_loss: 0.25185, step_acc: 9.60535, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 78, G_loss: 0.25154, step_acc: 9.61378, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 79, G_loss: 0.25122, step_acc: 9.62413, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 80, G_loss: 0.25083, step_acc: 9.63792, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 81, G_loss: 0.25034, step_acc: 9.64330, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 82, G_loss: 0.25004, step_acc: 9.65521, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 83, G_loss: 0.24956, step_acc: 9.66861, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 84, G_loss: 0.24904, step_acc: 9.67945, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 85, G_loss: 0.24877, step_acc: 9.68164, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 86, G_loss: 0.24868, step_acc: 9.69088, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 87, G_loss: 0.24846, step_acc: 9.69062, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 88, G_loss: 0.24833, step_acc: 9.69428, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 89, G_loss: 0.24831, step_acc: 9.69071, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 90, G_loss: 0.24828, step_acc: 9.69698, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 91, G_loss: 0.24809, step_acc: 9.69674, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 92, G_loss: 0.24800, step_acc: 9.70098, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 93, G_loss: 0.24799, step_acc: 9.69037, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 94, G_loss: 0.24813, step_acc: 9.70538, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 95, G_loss: 0.24773, step_acc: 9.69999, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 96, G_loss: 0.24773, step_acc: 9.70617, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 97, G_loss: 0.24763, step_acc: 9.69935, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 98, G_loss: 0.24773, step_acc: 9.70779, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 99, G_loss: 0.24755, step_acc: 9.69678, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 100, G_loss: 0.24776, step_acc: 9.70679, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 101, G_loss: 0.24759, step_acc: 9.68565, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 102, G_loss: 0.24802, step_acc: 9.70077, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 103, G_loss: 0.24788, step_acc: 9.67767, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 104, G_loss: 0.24823, step_acc: 9.70051, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 105, G_loss: 0.24784, step_acc: 9.68484, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 106, G_loss: 0.24793, step_acc: 9.69958, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 107, G_loss: 0.24777, step_acc: 9.68747, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 108, G_loss: 0.24769, step_acc: 9.70254, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 109, G_loss: 0.24746, step_acc: 9.70296, grid_scale: 1 / 5, strokes: 2 / 9
# iteration step 110, G_loss: 0.24699, step_acc: 9.87799, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 111, G_loss: 0.24067, step_acc: 9.96900, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 112, G_loss: 0.23666, step_acc: 10.05510, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 113, G_loss: 0.23304, step_acc: 10.11653, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 114, G_loss: 0.23088, step_acc: 10.13795, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 115, G_loss: 0.23010, step_acc: 10.22611, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 116, G_loss: 0.22593, step_acc: 10.26200, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 117, G_loss: 0.22436, step_acc: 10.28316, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 118, G_loss: 0.22327, step_acc: 10.35217, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 119, G_loss: 0.22144, step_acc: 10.42356, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 120, G_loss: 0.21980, step_acc: 10.53317, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 121, G_loss: 0.21745, step_acc: 10.59710, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 122, G_loss: 0.21515, step_acc: 10.64624, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 123, G_loss: 0.21394, step_acc: 10.72992, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 124, G_loss: 0.21121, step_acc: 10.81687, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 125, G_loss: 0.20859, step_acc: 10.86671, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 126, G_loss: 0.20665, step_acc: 10.86368, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 127, G_loss: 0.20675, step_acc: 10.91996, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 128, G_loss: 0.20470, step_acc: 10.98322, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 129, G_loss: 0.20282, step_acc: 10.98756, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 130, G_loss: 0.20246, step_acc: 11.06964, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 131, G_loss: 0.20013, step_acc: 11.10521, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 132, G_loss: 0.19906, step_acc: 11.19174, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 133, G_loss: 0.19708, step_acc: 11.26967, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 134, G_loss: 0.19524, step_acc: 11.36829, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 135, G_loss: 0.19319, step_acc: 11.46602, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 136, G_loss: 0.19079, step_acc: 11.57896, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 137, G_loss: 0.18845, step_acc: 11.75470, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 138, G_loss: 0.18529, step_acc: 11.91031, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 139, G_loss: 0.18236, step_acc: 12.02420, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 140, G_loss: 0.18031, step_acc: 12.15470, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 141, G_loss: 0.17740, step_acc: 12.25619, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 142, G_loss: 0.17480, step_acc: 12.38593, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 143, G_loss: 0.17228, step_acc: 12.48934, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 144, G_loss: 0.16966, step_acc: 12.55690, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 145, G_loss: 0.16832, step_acc: 12.58588, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 146, G_loss: 0.16755, step_acc: 12.66512, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 147, G_loss: 0.16548, step_acc: 12.72903, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 148, G_loss: 0.16369, step_acc: 12.80279, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 149, G_loss: 0.16271, step_acc: 12.81867, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 150, G_loss: 0.16178, step_acc: 12.89477, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 151, G_loss: 0.16037, step_acc: 12.94516, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 152, G_loss: 0.15947, step_acc: 13.02419, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 153, G_loss: 0.15843, step_acc: 13.04424, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 154, G_loss: 0.15820, step_acc: 13.07973, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 155, G_loss: 0.15820, step_acc: 13.05700, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 156, G_loss: 0.15798, step_acc: 13.13257, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 157, G_loss: 0.15701, step_acc: 13.09767, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 158, G_loss: 0.15695, step_acc: 13.12588, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 159, G_loss: 0.15691, step_acc: 13.10929, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 160, G_loss: 0.15707, step_acc: 13.15099, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 161, G_loss: 0.15666, step_acc: 13.12326, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 162, G_loss: 0.15662, step_acc: 13.14506, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 163, G_loss: 0.15636, step_acc: 13.14622, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 164, G_loss: 0.15636, step_acc: 13.13546, grid_scale: 1 / 5, strokes: 3 / 9
# iteration step 165, G_loss: 0.15633, step_acc: 13.30835, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 166, G_loss: 0.15459, step_acc: 13.42520, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 167, G_loss: 0.15223, step_acc: 13.49186, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 168, G_loss: 0.15211, step_acc: 13.57572, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 169, G_loss: 0.15115, step_acc: 13.47263, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 170, G_loss: 0.15218, step_acc: 13.63086, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 171, G_loss: 0.15051, step_acc: 13.71852, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 172, G_loss: 0.14921, step_acc: 13.65100, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 173, G_loss: 0.15026, step_acc: 13.78784, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 174, G_loss: 0.14830, step_acc: 13.82607, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 175, G_loss: 0.14794, step_acc: 13.82758, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 176, G_loss: 0.14785, step_acc: 13.87258, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 177, G_loss: 0.14718, step_acc: 13.90451, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 178, G_loss: 0.14684, step_acc: 13.91302, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 179, G_loss: 0.14667, step_acc: 13.92870, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 180, G_loss: 0.14642, step_acc: 13.88147, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 181, G_loss: 0.14704, step_acc: 13.96991, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 182, G_loss: 0.14608, step_acc: 13.98041, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 183, G_loss: 0.14581, step_acc: 13.97910, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 184, G_loss: 0.14569, step_acc: 13.95026, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 185, G_loss: 0.14628, step_acc: 14.03017, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 186, G_loss: 0.14551, step_acc: 14.02926, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 187, G_loss: 0.14518, step_acc: 14.00127, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 188, G_loss: 0.14580, step_acc: 14.04124, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 189, G_loss: 0.14523, step_acc: 14.08288, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 190, G_loss: 0.14463, step_acc: 14.07738, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 191, G_loss: 0.14443, step_acc: 14.08950, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 192, G_loss: 0.14458, step_acc: 14.01379, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 193, G_loss: 0.14538, step_acc: 14.06012, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 194, G_loss: 0.14487, step_acc: 14.08604, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 195, G_loss: 0.14444, step_acc: 14.09061, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 196, G_loss: 0.14444, step_acc: 14.06437, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 197, G_loss: 0.14460, step_acc: 14.08506, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 198, G_loss: 0.14465, step_acc: 14.09013, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 199, G_loss: 0.14419, step_acc: 14.11922, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 200, G_loss: 0.14414, step_acc: 14.09495, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 201, G_loss: 0.14408, step_acc: 14.11472, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 202, G_loss: 0.14416, step_acc: 14.05717, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 203, G_loss: 0.14455, step_acc: 14.09790, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 204, G_loss: 0.14456, step_acc: 14.09387, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 205, G_loss: 0.14395, step_acc: 14.14169, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 206, G_loss: 0.14388, step_acc: 14.10079, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 207, G_loss: 0.14382, step_acc: 14.13490, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 208, G_loss: 0.14392, step_acc: 14.08510, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 209, G_loss: 0.14423, step_acc: 14.05313, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 210, G_loss: 0.14478, step_acc: 14.04003, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 211, G_loss: 0.14474, step_acc: 14.11061, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 212, G_loss: 0.14401, step_acc: 14.10701, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 213, G_loss: 0.14363, step_acc: 14.12868, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 214, G_loss: 0.14354, step_acc: 14.11081, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 215, G_loss: 0.14362, step_acc: 14.11766, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 216, G_loss: 0.14367, step_acc: 14.11536, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 217, G_loss: 0.14369, step_acc: 14.05211, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 218, G_loss: 0.14447, step_acc: 14.13778, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 219, G_loss: 0.14354, step_acc: 14.15717, grid_scale: 1 / 5, strokes: 4 / 9
# iteration step 220, G_loss: 0.14312, step_acc: 14.37985, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 221, G_loss: 0.14077, step_acc: 14.21995, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 222, G_loss: 0.14223, step_acc: 14.62622, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 223, G_loss: 0.13738, step_acc: 14.55978, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 224, G_loss: 0.13699, step_acc: 14.62027, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 225, G_loss: 0.13685, step_acc: 14.65578, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 226, G_loss: 0.13611, step_acc: 14.66336, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 227, G_loss: 0.13626, step_acc: 14.61301, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 228, G_loss: 0.13628, step_acc: 14.69243, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 229, G_loss: 0.13604, step_acc: 14.67423, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 230, G_loss: 0.13556, step_acc: 14.77137, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 231, G_loss: 0.13485, step_acc: 14.73389, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 232, G_loss: 0.13479, step_acc: 14.76719, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 233, G_loss: 0.13467, step_acc: 14.72267, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 234, G_loss: 0.13473, step_acc: 14.68163, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 235, G_loss: 0.13591, step_acc: 14.71994, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 236, G_loss: 0.13525, step_acc: 14.76049, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 237, G_loss: 0.13464, step_acc: 14.70361, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 238, G_loss: 0.13518, step_acc: 14.73144, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 239, G_loss: 0.13519, step_acc: 14.78370, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 240, G_loss: 0.13414, step_acc: 14.81302, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 241, G_loss: 0.13407, step_acc: 14.74584, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 242, G_loss: 0.13456, step_acc: 14.81603, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 243, G_loss: 0.13412, step_acc: 14.76444, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 244, G_loss: 0.13447, step_acc: 14.80295, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 245, G_loss: 0.13423, step_acc: 14.77955, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 246, G_loss: 0.13431, step_acc: 14.80589, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 247, G_loss: 0.13408, step_acc: 14.80027, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 248, G_loss: 0.13418, step_acc: 14.77965, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 249, G_loss: 0.13439, step_acc: 14.78508, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 250, G_loss: 0.13447, step_acc: 14.80683, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 251, G_loss: 0.13396, step_acc: 14.81465, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 252, G_loss: 0.13414, step_acc: 14.75461, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 253, G_loss: 0.13442, step_acc: 14.79338, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 254, G_loss: 0.13445, step_acc: 14.74514, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 255, G_loss: 0.13435, step_acc: 14.82736, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 256, G_loss: 0.13409, step_acc: 14.76496, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 257, G_loss: 0.13403, step_acc: 14.83013, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 258, G_loss: 0.13421, step_acc: 14.76456, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 259, G_loss: 0.13417, step_acc: 14.80622, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 260, G_loss: 0.13443, step_acc: 14.75363, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 261, G_loss: 0.13415, step_acc: 14.83930, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 262, G_loss: 0.13389, step_acc: 14.76220, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 263, G_loss: 0.13409, step_acc: 14.84851, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 264, G_loss: 0.13381, step_acc: 14.76710, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 265, G_loss: 0.13399, step_acc: 14.86469, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 266, G_loss: 0.13376, step_acc: 14.78897, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 267, G_loss: 0.13393, step_acc: 14.84795, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 268, G_loss: 0.13367, step_acc: 14.79564, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 269, G_loss: 0.13381, step_acc: 14.85425, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 270, G_loss: 0.13367, step_acc: 14.79662, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 271, G_loss: 0.13389, step_acc: 14.85204, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 272, G_loss: 0.13369, step_acc: 14.77736, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 273, G_loss: 0.13415, step_acc: 14.82228, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 274, G_loss: 0.13428, step_acc: 14.76005, grid_scale: 1 / 5, strokes: 5 / 9
# iteration step 275, G_loss: 0.13420, step_acc: 14.88043, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 276, G_loss: 0.13326, step_acc: 14.75771, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 277, G_loss: 0.13386, step_acc: 14.84659, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 278, G_loss: 0.13341, step_acc: 14.82109, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 279, G_loss: 0.13303, step_acc: 14.91688, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 280, G_loss: 0.13233, step_acc: 14.85485, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 281, G_loss: 0.13229, step_acc: 14.84912, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 282, G_loss: 0.13223, step_acc: 14.85059, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 283, G_loss: 0.13210, step_acc: 14.84240, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 284, G_loss: 0.13208, step_acc: 14.83808, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 285, G_loss: 0.13165, step_acc: 14.90050, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 286, G_loss: 0.13125, step_acc: 14.84982, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 287, G_loss: 0.13101, step_acc: 14.88674, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 288, G_loss: 0.13148, step_acc: 14.72163, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 289, G_loss: 0.13232, step_acc: 14.89064, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 290, G_loss: 0.13089, step_acc: 14.88646, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 291, G_loss: 0.13039, step_acc: 14.93715, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 292, G_loss: 0.13024, step_acc: 14.87120, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 293, G_loss: 0.13025, step_acc: 14.92843, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 294, G_loss: 0.13021, step_acc: 14.88035, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 295, G_loss: 0.12991, step_acc: 14.99127, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 296, G_loss: 0.12942, step_acc: 14.96296, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 297, G_loss: 0.12888, step_acc: 15.02888, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 298, G_loss: 0.12883, step_acc: 15.01766, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 299, G_loss: 0.12822, step_acc: 15.00847, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 300, G_loss: 0.12908, step_acc: 15.04759, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 301, G_loss: 0.12766, step_acc: 15.10197, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 302, G_loss: 0.12741, step_acc: 15.08352, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 303, G_loss: 0.12712, step_acc: 15.08460, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 304, G_loss: 0.12719, step_acc: 15.09259, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 305, G_loss: 0.12675, step_acc: 15.13148, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 306, G_loss: 0.12639, step_acc: 15.12549, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 307, G_loss: 0.12631, step_acc: 15.11495, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 308, G_loss: 0.12634, step_acc: 15.16667, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 309, G_loss: 0.12564, step_acc: 15.16593, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 310, G_loss: 0.12552, step_acc: 15.17302, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 311, G_loss: 0.12531, step_acc: 15.18286, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 312, G_loss: 0.12525, step_acc: 15.19056, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 313, G_loss: 0.12510, step_acc: 15.19985, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 314, G_loss: 0.12499, step_acc: 15.20201, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 315, G_loss: 0.12476, step_acc: 15.22112, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 316, G_loss: 0.12476, step_acc: 15.20241, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 317, G_loss: 0.12461, step_acc: 15.26091, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 318, G_loss: 0.12440, step_acc: 15.18792, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 319, G_loss: 0.12469, step_acc: 15.21591, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 320, G_loss: 0.12497, step_acc: 15.20028, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 321, G_loss: 0.12458, step_acc: 15.27387, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 322, G_loss: 0.12421, step_acc: 15.28542, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 323, G_loss: 0.12390, step_acc: 15.26107, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 324, G_loss: 0.12398, step_acc: 15.25574, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 325, G_loss: 0.12428, step_acc: 15.18165, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 326, G_loss: 0.12478, step_acc: 15.26062, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 327, G_loss: 0.12425, step_acc: 15.26123, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 328, G_loss: 0.12418, step_acc: 15.25656, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 329, G_loss: 0.12429, step_acc: 15.21721, grid_scale: 1 / 5, strokes: 6 / 9
# iteration step 330, G_loss: 0.12467, step_acc: 15.14744, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 331, G_loss: 0.12562, step_acc: 15.15596, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 332, G_loss: 0.12504, step_acc: 15.32857, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 333, G_loss: 0.12302, step_acc: 15.28478, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 334, G_loss: 0.12304, step_acc: 15.33827, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 335, G_loss: 0.12276, step_acc: 15.27642, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 336, G_loss: 0.12270, step_acc: 15.35636, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 337, G_loss: 0.12227, step_acc: 15.32191, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 338, G_loss: 0.12222, step_acc: 15.35984, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 339, G_loss: 0.12192, step_acc: 15.30650, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 340, G_loss: 0.12216, step_acc: 15.37562, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 341, G_loss: 0.12152, step_acc: 15.34148, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 342, G_loss: 0.12142, step_acc: 15.36882, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 343, G_loss: 0.12171, step_acc: 15.31347, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 344, G_loss: 0.12177, step_acc: 15.40032, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 345, G_loss: 0.12121, step_acc: 15.32760, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 346, G_loss: 0.12149, step_acc: 15.42938, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 347, G_loss: 0.12094, step_acc: 15.36510, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 348, G_loss: 0.12103, step_acc: 15.43007, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 349, G_loss: 0.12062, step_acc: 15.39123, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 350, G_loss: 0.12068, step_acc: 15.43741, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 351, G_loss: 0.12058, step_acc: 15.33161, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 352, G_loss: 0.12102, step_acc: 15.41419, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 353, G_loss: 0.12068, step_acc: 15.36356, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 354, G_loss: 0.12084, step_acc: 15.42699, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 355, G_loss: 0.12042, step_acc: 15.38239, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 356, G_loss: 0.12064, step_acc: 15.42993, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 357, G_loss: 0.12035, step_acc: 15.38040, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 358, G_loss: 0.12082, step_acc: 15.43305, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 359, G_loss: 0.12034, step_acc: 15.38921, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 360, G_loss: 0.12042, step_acc: 15.45860, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 361, G_loss: 0.12006, step_acc: 15.40922, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 362, G_loss: 0.12022, step_acc: 15.41649, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 363, G_loss: 0.12040, step_acc: 15.37351, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 364, G_loss: 0.12080, step_acc: 15.40207, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 365, G_loss: 0.12054, step_acc: 15.36210, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 366, G_loss: 0.12093, step_acc: 15.46483, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 367, G_loss: 0.11987, step_acc: 15.43655, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 368, G_loss: 0.11963, step_acc: 15.47155, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 369, G_loss: 0.11959, step_acc: 15.44606, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 370, G_loss: 0.11960, step_acc: 15.48253, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 371, G_loss: 0.11932, step_acc: 15.43057, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 372, G_loss: 0.11952, step_acc: 15.48387, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 373, G_loss: 0.11929, step_acc: 15.37398, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 374, G_loss: 0.11998, step_acc: 15.45380, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 375, G_loss: 0.11963, step_acc: 15.42135, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 376, G_loss: 0.11954, step_acc: 15.50492, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 377, G_loss: 0.11901, step_acc: 15.43384, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 378, G_loss: 0.11912, step_acc: 15.51471, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 379, G_loss: 0.11873, step_acc: 15.44721, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 380, G_loss: 0.11889, step_acc: 15.47639, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 381, G_loss: 0.11915, step_acc: 15.34980, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 382, G_loss: 0.11993, step_acc: 15.44520, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 383, G_loss: 0.11981, step_acc: 15.37104, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 384, G_loss: 0.11953, step_acc: 15.49647, grid_scale: 1 / 5, strokes: 7 / 9
# iteration step 385, G_loss: 0.11910, step_acc: 15.26374, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 386, G_loss: 0.12062, step_acc: 15.49195, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 387, G_loss: 0.11886, step_acc: 15.49766, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 388, G_loss: 0.11824, step_acc: 15.55053, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 389, G_loss: 0.11807, step_acc: 15.56994, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 390, G_loss: 0.11771, step_acc: 15.55109, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 391, G_loss: 0.11776, step_acc: 15.59183, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 392, G_loss: 0.11747, step_acc: 15.59136, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 393, G_loss: 0.11730, step_acc: 15.58514, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 394, G_loss: 0.11733, step_acc: 15.55281, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 395, G_loss: 0.11795, step_acc: 15.39634, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 396, G_loss: 0.11940, step_acc: 15.38926, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 397, G_loss: 0.11986, step_acc: 15.55210, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 398, G_loss: 0.11759, step_acc: 15.59910, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 399, G_loss: 0.11709, step_acc: 15.65791, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 400, G_loss: 0.11676, step_acc: 15.56863, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 401, G_loss: 0.11694, step_acc: 15.65566, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 402, G_loss: 0.11674, step_acc: 15.55607, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 403, G_loss: 0.11716, step_acc: 15.48973, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 404, G_loss: 0.11828, step_acc: 15.48100, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 405, G_loss: 0.11803, step_acc: 15.55333, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 406, G_loss: 0.11678, step_acc: 15.55752, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 407, G_loss: 0.11711, step_acc: 15.37696, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 408, G_loss: 0.11907, step_acc: 15.38504, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 409, G_loss: 0.11927, step_acc: 15.53318, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 410, G_loss: 0.11701, step_acc: 15.48352, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 411, G_loss: 0.11786, step_acc: 15.37360, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 412, G_loss: 0.11918, step_acc: 15.41645, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 413, G_loss: 0.11877, step_acc: 15.55178, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 414, G_loss: 0.11760, step_acc: 15.34741, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 415, G_loss: 0.11939, step_acc: 15.47431, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 416, G_loss: 0.11831, step_acc: 15.54445, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 417, G_loss: 0.11729, step_acc: 15.62996, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 418, G_loss: 0.11639, step_acc: 15.61430, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 419, G_loss: 0.11662, step_acc: 15.57491, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 420, G_loss: 0.11671, step_acc: 15.62902, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 421, G_loss: 0.11668, step_acc: 15.59454, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 422, G_loss: 0.11660, step_acc: 15.56918, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 423, G_loss: 0.11733, step_acc: 15.46405, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 424, G_loss: 0.11812, step_acc: 15.53658, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 425, G_loss: 0.11779, step_acc: 15.55381, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 426, G_loss: 0.11707, step_acc: 15.64978, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 427, G_loss: 0.11644, step_acc: 15.61311, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 428, G_loss: 0.11633, step_acc: 15.64196, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 429, G_loss: 0.11624, step_acc: 15.62799, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 430, G_loss: 0.11653, step_acc: 15.63652, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 431, G_loss: 0.11628, step_acc: 15.56150, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 432, G_loss: 0.11671, step_acc: 15.63344, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 433, G_loss: 0.11630, step_acc: 15.66363, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 434, G_loss: 0.11613, step_acc: 15.61951, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 435, G_loss: 0.11632, step_acc: 15.62894, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 436, G_loss: 0.11635, step_acc: 15.57520, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 437, G_loss: 0.11680, step_acc: 15.53698, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 438, G_loss: 0.11746, step_acc: 15.53149, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 439, G_loss: 0.11746, step_acc: 15.60429, grid_scale: 1 / 5, strokes: 8 / 9
# iteration step 440, G_loss: 0.11674, step_acc: 15.31780, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 441, G_loss: 0.11998, step_acc: 15.47943, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 442, G_loss: 0.11768, step_acc: 15.60234, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 443, G_loss: 0.11677, step_acc: 15.63716, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 444, G_loss: 0.11609, step_acc: 15.68193, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 445, G_loss: 0.11575, step_acc: 15.71038, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 446, G_loss: 0.11534, step_acc: 15.67584, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 447, G_loss: 0.11568, step_acc: 15.69492, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 448, G_loss: 0.11543, step_acc: 15.66977, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 449, G_loss: 0.11546, step_acc: 15.69870, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 450, G_loss: 0.11545, step_acc: 15.66455, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 451, G_loss: 0.11592, step_acc: 15.72632, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 452, G_loss: 0.11530, step_acc: 15.62621, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 453, G_loss: 0.11569, step_acc: 15.69540, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 454, G_loss: 0.11561, step_acc: 15.58657, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 455, G_loss: 0.11599, step_acc: 15.72140, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 456, G_loss: 0.11509, step_acc: 15.64516, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 457, G_loss: 0.11523, step_acc: 15.72595, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 458, G_loss: 0.11503, step_acc: 15.64506, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 459, G_loss: 0.11573, step_acc: 15.68594, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 460, G_loss: 0.11547, step_acc: 15.62822, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 461, G_loss: 0.11555, step_acc: 15.70249, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 462, G_loss: 0.11522, step_acc: 15.67042, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 463, G_loss: 0.11534, step_acc: 15.73819, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 464, G_loss: 0.11482, step_acc: 15.65287, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 465, G_loss: 0.11543, step_acc: 15.65138, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 466, G_loss: 0.11565, step_acc: 15.68888, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 467, G_loss: 0.11522, step_acc: 15.73112, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 468, G_loss: 0.11493, step_acc: 15.66111, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 469, G_loss: 0.11560, step_acc: 15.76107, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 470, G_loss: 0.11466, step_acc: 15.63609, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 471, G_loss: 0.11532, step_acc: 15.77673, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 472, G_loss: 0.11449, step_acc: 15.67542, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 473, G_loss: 0.11504, step_acc: 15.71029, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 474, G_loss: 0.11517, step_acc: 15.71132, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 475, G_loss: 0.11501, step_acc: 15.77656, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 476, G_loss: 0.11450, step_acc: 15.68687, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 477, G_loss: 0.11504, step_acc: 15.70059, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 478, G_loss: 0.11527, step_acc: 15.68529, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 479, G_loss: 0.11531, step_acc: 15.70460, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 480, G_loss: 0.11505, step_acc: 15.71017, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 481, G_loss: 0.11486, step_acc: 15.71335, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 482, G_loss: 0.11488, step_acc: 15.70700, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 483, G_loss: 0.11474, step_acc: 15.75765, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 484, G_loss: 0.11439, step_acc: 15.73238, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 485, G_loss: 0.11469, step_acc: 15.71583, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 486, G_loss: 0.11470, step_acc: 15.73248, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 487, G_loss: 0.11491, step_acc: 15.66709, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 488, G_loss: 0.11511, step_acc: 15.73743, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 489, G_loss: 0.11465, step_acc: 15.75017, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 490, G_loss: 0.11453, step_acc: 15.70529, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 491, G_loss: 0.11501, step_acc: 15.72306, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 492, G_loss: 0.11496, step_acc: 15.69573, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 493, G_loss: 0.11534, step_acc: 15.75078, grid_scale: 1 / 5, strokes: 9 / 9
# iteration step 494, G_loss: 0.11461, step_acc: 15.73794, grid_scale: 1 / 5, strokes: 9 / 9
# rendering canvas...
# iteration step 0, G_loss: 0.11458, step_acc: 14.54572, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 1, G_loss: 0.12797, step_acc: 14.58865, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 2, G_loss: 0.12745, step_acc: 14.70012, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 3, G_loss: 0.12577, step_acc: 14.70717, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 4, G_loss: 0.12519, step_acc: 14.75239, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 5, G_loss: 0.12465, step_acc: 14.74491, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 6, G_loss: 0.12440, step_acc: 14.84052, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 7, G_loss: 0.12316, step_acc: 14.85682, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 8, G_loss: 0.12288, step_acc: 14.87554, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 9, G_loss: 0.12252, step_acc: 14.90151, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 10, G_loss: 0.12216, step_acc: 14.92194, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 11, G_loss: 0.12181, step_acc: 14.94309, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 12, G_loss: 0.12150, step_acc: 14.97210, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 13, G_loss: 0.12108, step_acc: 15.00983, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 14, G_loss: 0.12060, step_acc: 15.09468, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 15, G_loss: 0.11961, step_acc: 15.19599, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 16, G_loss: 0.11848, step_acc: 15.25563, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 17, G_loss: 0.11785, step_acc: 15.25049, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 18, G_loss: 0.11784, step_acc: 15.31100, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 19, G_loss: 0.11724, step_acc: 15.31638, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 20, G_loss: 0.11712, step_acc: 15.37161, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 21, G_loss: 0.11669, step_acc: 15.39202, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 22, G_loss: 0.11632, step_acc: 15.43449, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 23, G_loss: 0.11583, step_acc: 15.46488, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 24, G_loss: 0.11544, step_acc: 15.47224, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 25, G_loss: 0.11535, step_acc: 15.47056, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 26, G_loss: 0.11547, step_acc: 15.48135, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 27, G_loss: 0.11531, step_acc: 15.50796, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 28, G_loss: 0.11497, step_acc: 15.53988, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 29, G_loss: 0.11469, step_acc: 15.55352, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 30, G_loss: 0.11444, step_acc: 15.57045, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 31, G_loss: 0.11436, step_acc: 15.55670, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 32, G_loss: 0.11446, step_acc: 15.57035, grid_scale: 2 / 5, strokes: 1 / 9
# iteration step 33, G_loss: 0.11453, step_acc: 15.58469, grid_scale: 2 / 5, strokes: 1 / 9
# ...
# iteration step 320, G_loss: 0.04491, step_acc: 23.68783, grid_scale: 5 / 5, strokes: 6 / 9
# iteration step 321, G_loss: 0.04493, step_acc: 23.69706, grid_scale: 5 / 5, strokes: 6 / 9
# iteration step 322, G_loss: 0.04491, step_acc: 23.69095, grid_scale: 5 / 5, strokes: 6 / 9
# iteration step 323, G_loss: 0.04494, step_acc: 23.69034, grid_scale: 5 / 5, strokes: 6 / 9
# iteration step 324, G_loss: 0.04492, step_acc: 23.69473, grid_scale: 5 / 5, strokes: 6 / 9
# iteration step 325, G_loss: 0.04492, step_acc: 23.68282, grid_scale: 5 / 5, strokes: 6 / 9
# iteration step 326, G_loss: 0.04492, step_acc: 23.68554, grid_scale: 5 / 5, strokes: 6 / 9
# iteration step 327, G_loss: 0.04497, step_acc: 23.70191, grid_scale: 5 / 5, strokes: 6 / 9
# iteration step 328, G_loss: 0.04488, step_acc: 23.70221, grid_scale: 5 / 5, strokes: 6 / 9
# iteration step 329, G_loss: 0.04487, step_acc: 23.70365, grid_scale: 5 / 5, strokes: 6 / 9
# iteration step 330, G_loss: 0.04487, step_acc: 23.19208, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 331, G_loss: 0.04595, step_acc: 23.57880, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 332, G_loss: 0.04511, step_acc: 23.66540, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 333, G_loss: 0.04481, step_acc: 23.70931, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 334, G_loss: 0.04466, step_acc: 23.73664, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 335, G_loss: 0.04459, step_acc: 23.74508, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 336, G_loss: 0.04451, step_acc: 23.75144, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 337, G_loss: 0.04448, step_acc: 23.75930, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 338, G_loss: 0.04441, step_acc: 23.76333, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 339, G_loss: 0.04441, step_acc: 23.77143, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 340, G_loss: 0.04435, step_acc: 23.76533, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 341, G_loss: 0.04439, step_acc: 23.77256, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 342, G_loss: 0.04435, step_acc: 23.76653, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 343, G_loss: 0.04435, step_acc: 23.77861, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 344, G_loss: 0.04429, step_acc: 23.77624, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 345, G_loss: 0.04430, step_acc: 23.78539, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 346, G_loss: 0.04425, step_acc: 23.77506, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 347, G_loss: 0.04428, step_acc: 23.78517, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 348, G_loss: 0.04426, step_acc: 23.79450, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 349, G_loss: 0.04422, step_acc: 23.79577, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 350, G_loss: 0.04420, step_acc: 23.78747, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 351, G_loss: 0.04424, step_acc: 23.79507, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 352, G_loss: 0.04421, step_acc: 23.79831, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 353, G_loss: 0.04419, step_acc: 23.80115, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 354, G_loss: 0.04419, step_acc: 23.79829, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 355, G_loss: 0.04421, step_acc: 23.80682, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 356, G_loss: 0.04416, step_acc: 23.80688, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 357, G_loss: 0.04414, step_acc: 23.81368, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 358, G_loss: 0.04412, step_acc: 23.80894, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 359, G_loss: 0.04413, step_acc: 23.81311, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 360, G_loss: 0.04411, step_acc: 23.81851, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 361, G_loss: 0.04408, step_acc: 23.81849, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 362, G_loss: 0.04408, step_acc: 23.80834, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 363, G_loss: 0.04413, step_acc: 23.81486, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 364, G_loss: 0.04409, step_acc: 23.82215, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 365, G_loss: 0.04407, step_acc: 23.82450, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 366, G_loss: 0.04405, step_acc: 23.82088, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 367, G_loss: 0.04406, step_acc: 23.82765, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 368, G_loss: 0.04405, step_acc: 23.82402, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 369, G_loss: 0.04406, step_acc: 23.83589, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 370, G_loss: 0.04403, step_acc: 23.82824, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 371, G_loss: 0.04404, step_acc: 23.82805, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 372, G_loss: 0.04404, step_acc: 23.82464, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 373, G_loss: 0.04402, step_acc: 23.84283, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 374, G_loss: 0.04397, step_acc: 23.83322, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 375, G_loss: 0.04401, step_acc: 23.83218, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 376, G_loss: 0.04400, step_acc: 23.83127, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 377, G_loss: 0.04401, step_acc: 23.84405, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 378, G_loss: 0.04396, step_acc: 23.83091, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 379, G_loss: 0.04399, step_acc: 23.82433, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 380, G_loss: 0.04400, step_acc: 23.83136, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 381, G_loss: 0.04400, step_acc: 23.83439, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 382, G_loss: 0.04398, step_acc: 23.82636, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 383, G_loss: 0.04400, step_acc: 23.84316, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 384, G_loss: 0.04394, step_acc: 23.82871, grid_scale: 5 / 5, strokes: 7 / 9
# iteration step 385, G_loss: 0.04399, step_acc: 23.69563, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 386, G_loss: 0.04430, step_acc: 23.75885, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 387, G_loss: 0.04419, step_acc: 23.86891, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 388, G_loss: 0.04375, step_acc: 23.87915, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 389, G_loss: 0.04374, step_acc: 23.90926, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 390, G_loss: 0.04363, step_acc: 23.92220, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 391, G_loss: 0.04356, step_acc: 23.93977, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 392, G_loss: 0.04346, step_acc: 23.93657, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 393, G_loss: 0.04349, step_acc: 23.95912, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 394, G_loss: 0.04340, step_acc: 23.95201, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 395, G_loss: 0.04343, step_acc: 23.94402, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 396, G_loss: 0.04342, step_acc: 23.95458, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 397, G_loss: 0.04342, step_acc: 23.98123, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 398, G_loss: 0.04330, step_acc: 23.98552, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 399, G_loss: 0.04329, step_acc: 23.99238, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 400, G_loss: 0.04325, step_acc: 23.99078, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 401, G_loss: 0.04327, step_acc: 23.99903, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 402, G_loss: 0.04326, step_acc: 23.99065, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 403, G_loss: 0.04329, step_acc: 24.00811, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 404, G_loss: 0.04320, step_acc: 23.99730, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 405, G_loss: 0.04324, step_acc: 24.01423, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 406, G_loss: 0.04317, step_acc: 24.00121, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 407, G_loss: 0.04322, step_acc: 24.01053, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 408, G_loss: 0.04317, step_acc: 24.01311, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 409, G_loss: 0.04316, step_acc: 24.02486, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 410, G_loss: 0.04313, step_acc: 24.02245, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 411, G_loss: 0.04313, step_acc: 24.03113, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 412, G_loss: 0.04309, step_acc: 24.02714, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 413, G_loss: 0.04309, step_acc: 24.03448, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 414, G_loss: 0.04308, step_acc: 24.02972, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 415, G_loss: 0.04309, step_acc: 24.02794, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 416, G_loss: 0.04312, step_acc: 24.03052, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 417, G_loss: 0.04311, step_acc: 24.05147, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 418, G_loss: 0.04305, step_acc: 24.02909, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 419, G_loss: 0.04309, step_acc: 24.04140, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 420, G_loss: 0.04304, step_acc: 24.04388, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 421, G_loss: 0.04303, step_acc: 24.05843, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 422, G_loss: 0.04299, step_acc: 24.06169, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 423, G_loss: 0.04299, step_acc: 24.06000, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 424, G_loss: 0.04299, step_acc: 24.04314, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 425, G_loss: 0.04302, step_acc: 24.04909, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 426, G_loss: 0.04300, step_acc: 24.03939, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 427, G_loss: 0.04303, step_acc: 24.04568, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 428, G_loss: 0.04300, step_acc: 24.04145, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 429, G_loss: 0.04302, step_acc: 24.04536, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 430, G_loss: 0.04303, step_acc: 24.04582, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 431, G_loss: 0.04303, step_acc: 24.05703, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 432, G_loss: 0.04295, step_acc: 24.05089, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 433, G_loss: 0.04298, step_acc: 24.06186, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 434, G_loss: 0.04295, step_acc: 24.05163, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 435, G_loss: 0.04297, step_acc: 24.06219, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 436, G_loss: 0.04294, step_acc: 24.05620, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 437, G_loss: 0.04297, step_acc: 24.07063, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 438, G_loss: 0.04288, step_acc: 24.07222, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 439, G_loss: 0.04290, step_acc: 24.07734, grid_scale: 5 / 5, strokes: 8 / 9
# iteration step 440, G_loss: 0.04288, step_acc: 23.70547, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 441, G_loss: 0.04373, step_acc: 23.88133, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 442, G_loss: 0.04336, step_acc: 24.04943, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 443, G_loss: 0.04284, step_acc: 24.11046, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 444, G_loss: 0.04265, step_acc: 24.10909, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 445, G_loss: 0.04265, step_acc: 24.14426, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 446, G_loss: 0.04253, step_acc: 24.14238, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 447, G_loss: 0.04251, step_acc: 24.14576, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 448, G_loss: 0.04252, step_acc: 24.12780, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 449, G_loss: 0.04254, step_acc: 24.13664, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 450, G_loss: 0.04251, step_acc: 24.16398, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 451, G_loss: 0.04248, step_acc: 24.15319, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 452, G_loss: 0.04246, step_acc: 24.17202, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 453, G_loss: 0.04241, step_acc: 24.17489, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 454, G_loss: 0.04240, step_acc: 24.18875, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 455, G_loss: 0.04237, step_acc: 24.16746, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 456, G_loss: 0.04241, step_acc: 24.19550, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 457, G_loss: 0.04234, step_acc: 24.19199, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 458, G_loss: 0.04236, step_acc: 24.20557, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 459, G_loss: 0.04230, step_acc: 24.18771, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 460, G_loss: 0.04235, step_acc: 24.20738, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 461, G_loss: 0.04228, step_acc: 24.22488, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 462, G_loss: 0.04226, step_acc: 24.22421, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 463, G_loss: 0.04224, step_acc: 24.22512, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 464, G_loss: 0.04223, step_acc: 24.23313, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 465, G_loss: 0.04221, step_acc: 24.23907, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 466, G_loss: 0.04217, step_acc: 24.23438, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 467, G_loss: 0.04221, step_acc: 24.24543, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 468, G_loss: 0.04215, step_acc: 24.22990, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 469, G_loss: 0.04221, step_acc: 24.22996, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 470, G_loss: 0.04220, step_acc: 24.24431, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 471, G_loss: 0.04216, step_acc: 24.23260, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 472, G_loss: 0.04218, step_acc: 24.23782, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 473, G_loss: 0.04217, step_acc: 24.24445, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 474, G_loss: 0.04212, step_acc: 24.25617, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 475, G_loss: 0.04211, step_acc: 24.26215, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 476, G_loss: 0.04209, step_acc: 24.24792, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 477, G_loss: 0.04214, step_acc: 24.24634, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 478, G_loss: 0.04213, step_acc: 24.25633, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 479, G_loss: 0.04208, step_acc: 24.25470, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 480, G_loss: 0.04212, step_acc: 24.25981, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 481, G_loss: 0.04209, step_acc: 24.26046, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 482, G_loss: 0.04206, step_acc: 24.26237, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 483, G_loss: 0.04207, step_acc: 24.28280, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 484, G_loss: 0.04198, step_acc: 24.28018, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 485, G_loss: 0.04200, step_acc: 24.28745, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 486, G_loss: 0.04198, step_acc: 24.28935, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 487, G_loss: 0.04195, step_acc: 24.28343, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 488, G_loss: 0.04197, step_acc: 24.28286, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 489, G_loss: 0.04199, step_acc: 24.27927, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 490, G_loss: 0.04197, step_acc: 24.29117, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 491, G_loss: 0.04196, step_acc: 24.28933, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 492, G_loss: 0.04194, step_acc: 24.28757, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 493, G_loss: 0.04198, step_acc: 24.29555, grid_scale: 5 / 5, strokes: 9 / 9
# iteration step 494, G_loss: 0.04193, step_acc: 24.29905, grid_scale: 5 / 5, strokes: 9 / 9
# rendering canvas...
# saving stroke parameters...
# rendering canvas...

# %% [markdown]
# Check out your animated results at args.output_dir. Before you download that folder, let's first have a look at what the generated painting looks like.

# %%
plt.imshow(final_rendered_image), plt.title('generated')
plt.show()
